# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
from google.cloud import bigquery

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/Users/seyedehmarziehhosseini/Downloads/Frauenloopproject-e79e2813e4fb.json"

# %%
#Aaustin crime
client = bigquery.Client() #start big query client

QUERY = (
    'SELECT * FROM  `bigquery-public-data.austin_crime.crime` '
    'ORDER BY primary_type DESC,year DESC,district DESC')

query_job = client.query(QUERY)    # Start Query API Request
query_result = query_job.result()  # Get Query Result
crime_Austin = query_result.to_dataframe()  #save the query result to data frame
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: PyarrowMissingWarning: Converting to a dataframe without pyarrow installed is often slower and will become unsupported in the future. Please install the pyarrow package.
#   # Remove the CWD from sys.path while we load stuff.

# %%
crime_Austin
# Out:
#           unique_key                                            address  \
# 0       2.014503e+10              7522 N IH 35 SVRD SBAustin, TX 78752s
# 1       2.014800e+10  7703 N LAMAR BLVD NBAustin, TX 78752s(30.34520...
# 2       2.014505e+10  7703 N LAMAR BLVD NBAustin, TX 78752s(30.34520...
# 3       2.014176e+10  7113 BURNET RDAustin, TX 78757s(30.347797, -97...
# 4       2.014502e+10  7113 BURNET RDAustin, TX 78757s(30.347797, -97...
# 5       2.014501e+10         6300 E US 290 HWY SVRD WBAustin, TX 78752s
# 6       2.014503e+10  7480 CAMERON RDAustin, TX 78752s(30.330117, -9...
# 7       2.014800e+10  1016 LA POSADA DRAustin, TX 78752s(30.325532, ...
# 8       2.014800e+10  5607 SUNSHINE DRAustin, TX 78756s(30.326053, -...
# 9       2.014800e+10  5900 GUADALUPE STAustin, TX 78752s(30.325847, ...
# 10      2.014502e+10  6929 AIRPORT BLVDAustin, TX 78752s(30.336574, ...
# 11      2.014800e+10  916 E KOENIG LN WBAustin, TX 78752s(30.321568,...
# ...

# %%
crime_Austin['primary_type'].value_counts(sort=True)
# Out:
# Theft                                           54515
# Theft: All Other Larceny                        13539
# Theft: BOV                                      10545
# Burglary                                        10098
# Auto Theft                                       6231
# Burglary / Breaking & Entering                   5670
# Theft: Shoplifting                               4284
# Agg Assault                                      4092
# Robbery                                          2859
# Aggravated Assault                               1888
# Rape                                             1801
# Theft: Pocket Picking                             448
# Theft: Auto Parts                                 231
# Theft: from Building                              221
# Theft: Coin Op Machine                            153
# Murder                                             61
# Homicide: Murder & Nonnegligent Manslaughter       32
# ...

# %%
ca_filtered = crime_Austin[(crime_Austin['year'] == 2015)] #equivalnet of np.where in python

ca_filtered

ca_filtered['primary_type'].value_counts(sort=True)
# Out:
# Theft          28274
# Burglary        4927
# Auto Theft      2018
# Agg Assault     1915
# Robbery          935
# Rape             481
# Murder            23
# Name: primary_type, dtype: int64

# %%
class Analyze_Crime:
    
    def __init__ (self, dataset):
        
        self.dataset = dataset
        
    
    def crimetype (self,year): #shows number of crimes per given year
        
        data_cut = self.dataset[(self.dataset['year'] == year)]
        print(data_cut['primary_type'].value_counts(sort=True))

# %%
d = Analyze_Crime(crime_Austin)

d.crimetype(2014)
# Out:
# Theft: All Other Larceny                        13539
# Theft: BOV                                      10545
# Burglary / Breaking & Entering                   5670
# Theft: Shoplifting                               4284
# Auto Theft                                       2188
# Aggravated Assault                               1888
# Robbery                                           874
# Rape                                              561
# Theft: Pocket Picking                             448
# Theft: Auto Parts                                 231
# Theft: from Building                              221
# Theft: Coin Op Machine                            153
# Homicide: Murder & Nonnegligent Manslaughter       32
# Theft: Purse Snatching                              7
# Name: primary_type, dtype: int64

# %%
from IPython.display import Image

# %%
Image(filename = 'files/crimeanalyze.png', width = 600, height = 600)
